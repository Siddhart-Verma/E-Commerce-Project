# %%
import pandas as pd

train = pd.read_csv("merged_dataset/merged_dataset_in_train.csv")

test = pd.read_csv("merged_dataset/merged_dataset_in_test.csv",)
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_23852\2810233384.py:3: DtypeWarning: Columns (6,7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv("merged_dataset/merged_dataset_in_train.csv")

# %%
print(train.head(10))
print(test.head(10))
# Out:
#    id        date  store_nbr  item_nbr  unit_sales  onpromotion Day_type  \
# 0   0  2013-01-01         25    103665         7.0        False  Holiday
# 1   1  2013-01-01         25    105574         1.0        False  Holiday
# 2   2  2013-01-01         25    105575         2.0        False  Holiday
# 3   3  2013-01-01         25    108079         1.0        False  Holiday
# 4   4  2013-01-01         25    108701         1.0        False  Holiday
# 5   5  2013-01-01         25    108786         3.0        False  Holiday
# 6   6  2013-01-01         25    108797         1.0        False  Holiday
# 7   7  2013-01-01         25    108952         1.0        False  Holiday
# 8   8  2013-01-01         25    111397        13.0        False  Holiday
# 9   9  2013-01-01         25    114790         3.0        False  Holiday
#
#      locale locale_name         description transferred        family  class  \
# 0  National     Ecuador  Primer dia del ano       False  BREAD/BAKERY   2712
# ...

# %%
train.isnull().sum()
test.isnull().sum()
# Out:
# id                    0
# date                  0
# store_nbr             0
# item_nbr              0
# onpromotion           0
# family                0
# class                 0
# perishable            0
# dcoilwtico       842616
# city                  0
# state                 0
# store_grade           0
# cluster               0
# transactions    3370464
# dtype: int64

# %%
print(train['Day_type'].unique())
# Out:
# ['Holiday' nan 'Work Day']

# %%
test = test.drop(columns=['transactions'])

# %%
test.head()
# Out:
#           id        date  store_nbr  item_nbr  onpromotion        family  \
# 0  125497040  2017-08-16          1     96995        False     GROCERY I
# 1  125497041  2017-08-16          1     99197        False     GROCERY I
# 2  125497042  2017-08-16          1    103501        False      CLEANING
# 3  125497043  2017-08-16          1    103520        False     GROCERY I
# 4  125497044  2017-08-16          1    103665        False  BREAD/BAKERY
#
#    class  perishable  dcoilwtico   city      state store_grade  cluster
# 0   1093           0        46.8  Quito  Pichincha           D       13
# 1   1067           0        46.8  Quito  Pichincha           D       13
# 2   3008           0        46.8  Quito  Pichincha           D       13
# 3   1028           0        46.8  Quito  Pichincha           D       13
# 4   2712           1        46.8  Quito  Pichincha           D       13

# %%
print(test.dtypes)
print(train.dtypes)
# Out:
# id               int64
# date            object
# store_nbr        int64
# item_nbr         int64
# onpromotion       bool
# family          object
# class            int64
# perishable       int64
# dcoilwtico     float64
# city            object
# state           object
# store_grade     object
# cluster          int64
# dtype: object
# id                int64
# date             object
# store_nbr         int64
# item_nbr          int64
# unit_sales      float64
# onpromotion        bool
# Day_type         object
# locale           object
# locale_name      object
# description      object
# transferred      object
# family           object
# class             int64
# perishable        int64
# dcoilwtico      float64
# city             object
# state            object
# store_grade      object
# cluster           int64
# transactions      int64
# dtype: object

# %%
train['date'] = pd.to_datetime(train['date'])
test['date'] = pd.to_datetime(test['date'])

# %%
print(train.dtypes)
print(test.dtypes)
# Out:
# id                       int64
# date            datetime64[ns]
# store_nbr                int64
# item_nbr                 int64
# unit_sales             float64
# onpromotion               bool
# Day_type                object
# locale                  object
# locale_name             object
# description             object
# transferred             object
# family                  object
# class                    int64
# perishable               int64
# dcoilwtico             float64
# city                    object
# state                   object
# store_grade             object
# cluster                  int64
# transactions             int64
# dtype: object
# id                      int64
# date           datetime64[ns]
# store_nbr               int64
# item_nbr                int64
# onpromotion              bool
# family                 object
# class                   int64
# perishable              int64
# dcoilwtico            float64
# city                   object
# ...

# %%
# check shape of the file (no of rows and no of columns)

# for test file
test.shape


#for train file
train.shape
# Out:
# (1000000, 20)

# %%
# check for info about file

#for train file
print(train.info())


#for test file
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 20 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   id            1000000 non-null  int64
#  1   date          1000000 non-null  datetime64[ns]
#  2   store_nbr     1000000 non-null  int64
#  3   item_nbr      1000000 non-null  int64
#  4   unit_sales    1000000 non-null  float64
#  5   onpromotion   1000000 non-null  bool
#  6   Day_type      85286 non-null    object
#  7   locale        85286 non-null    object
#  8   locale_name   85286 non-null    object
#  9   description   85286 non-null    object
#  10  transferred   85286 non-null    object
#  11  family        1000000 non-null  object
#  12  class         1000000 non-null  int64
#  13  perishable    1000000 non-null  int64
#  14  dcoilwtico    712906 non-null   float64
#  15  city          1000000 non-null  object
#  16  state         1000000 non-null  object
# ...

# %%
# check missing value

# of train file
print(test.isnull().sum())


#for test file
print(train.isnull().sum())
# Out:
# id                  0
# date                0
# store_nbr           0
# item_nbr            0
# onpromotion         0
# family              0
# class               0
# perishable          0
# dcoilwtico     842616
# city                0
# state               0
# store_grade         0
# cluster             0
# dtype: int64
# id                   0
# date                 0
# store_nbr            0
# item_nbr             0
# unit_sales           0
# onpromotion          0
# Day_type        914714
# locale          914714
# locale_name     914714
# description     914714
# transferred     914714
# family               0
# class                0
# perishable           0
# dcoilwtico      287094
# city                 0
# state                0
# store_grade          0
# cluster              0
# transactions         0
# dtype: int64

# %%
#Fill the NaNs with Default or Meaningful Values


# for test_file

test['dcoilwtico']=test['dcoilwtico'].fillna(test['dcoilwtico'].mean())

# for train dataset
train['dcoilwtico']=train['dcoilwtico'].fillna(train['dcoilwtico'].mean())
train['Day_type']=train['Day_type'].fillna("Unknown")
train['locale']= train['locale'].fillna("Unknown")
train['locale_name']=train['locale_name'].fillna("Unknown")
train['description']=train['description'].fillna("Unknown")
train['transferred']=train['transferred'].fillna("Unknown")

# %%
print(train.head())
print(test.head())
# Out:
#    id       date  store_nbr  item_nbr  unit_sales  onpromotion Day_type  \
# 0   0 2013-01-01         25    103665         7.0        False  Holiday
# 1   1 2013-01-01         25    105574         1.0        False  Holiday
# 2   2 2013-01-01         25    105575         2.0        False  Holiday
# 3   3 2013-01-01         25    108079         1.0        False  Holiday
# 4   4 2013-01-01         25    108701         1.0        False  Holiday
#
#      locale locale_name         description transferred        family  class  \
# 0  National     Ecuador  Primer dia del ano       False  BREAD/BAKERY   2712
# 1  National     Ecuador  Primer dia del ano       False     GROCERY I   1045
# 2  National     Ecuador  Primer dia del ano       False     GROCERY I   1045
# 3  National     Ecuador  Primer dia del ano       False     GROCERY I   1030
# 4  National     Ecuador  Primer dia del ano       False          DELI   2644
#
# ...

# %%
#check missing after fill it 


#for test file
print(test.isnull().sum())
print(train.isnull().sum())

# for train file
#print(em.isnull().sum())
# Out:
# id             0
# date           0
# store_nbr      0
# item_nbr       0
# onpromotion    0
# family         0
# class          0
# perishable     0
# dcoilwtico     0
# city           0
# state          0
# store_grade    0
# cluster        0
# dtype: int64
# id              0
# date            0
# store_nbr       0
# item_nbr        0
# unit_sales      0
# onpromotion     0
# Day_type        0
# locale          0
# locale_name     0
# description     0
# transferred     0
# family          0
# class           0
# perishable      0
# dcoilwtico      0
# city            0
# state           0
# store_grade     0
# cluster         0
# transactions    0
# dtype: int64

# %%
#check for duplicate rows

# for test file
print(test.duplicated().sum())
print(train.duplicated().sum())

# for train file
#em.duplicated()
# Out:
# 0
# 0

# %%
# final check after every changes

# for train file
print(train.head())


# for test file
print(test.head())
# Out:
#    id       date  store_nbr  item_nbr  unit_sales  onpromotion Day_type  \
# 0   0 2013-01-01         25    103665         7.0        False  Holiday
# 1   1 2013-01-01         25    105574         1.0        False  Holiday
# 2   2 2013-01-01         25    105575         2.0        False  Holiday
# 3   3 2013-01-01         25    108079         1.0        False  Holiday
# 4   4 2013-01-01         25    108701         1.0        False  Holiday
#
#      locale locale_name         description transferred        family  class  \
# 0  National     Ecuador  Primer dia del ano       False  BREAD/BAKERY   2712
# 1  National     Ecuador  Primer dia del ano       False     GROCERY I   1045
# 2  National     Ecuador  Primer dia del ano       False     GROCERY I   1045
# 3  National     Ecuador  Primer dia del ano       False     GROCERY I   1030
# 4  National     Ecuador  Primer dia del ano       False          DELI   2644
#
# ...

# %%
# for train file
train.shape


# for test file
test.shape
# Out:
# (3370464, 13)

# %%
# for train file
train.info()


#for test file
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 20 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   id            1000000 non-null  int64
#  1   date          1000000 non-null  datetime64[ns]
#  2   store_nbr     1000000 non-null  int64
#  3   item_nbr      1000000 non-null  int64
#  4   unit_sales    1000000 non-null  float64
#  5   onpromotion   1000000 non-null  bool
#  6   Day_type      1000000 non-null  object
#  7   locale        1000000 non-null  object
#  8   locale_name   1000000 non-null  object
#  9   description   1000000 non-null  object
#  10  transferred   1000000 non-null  object
#  11  family        1000000 non-null  object
#  12  class         1000000 non-null  int64
#  13  perishable    1000000 non-null  int64
#  14  dcoilwtico    1000000 non-null  float64
#  15  city          1000000 non-null  object
#  16  state         1000000 non-null  object
# ...

# %%
# for train file
train.describe()


#for test file
test.describe()
# Out:
#                  id                           date     store_nbr  \
# count  3.370464e+06                        3370464  3.370464e+06
# mean   1.271823e+08  2017-08-23 12:00:00.000003072  2.750000e+01
# min    1.254970e+08            2017-08-16 00:00:00  1.000000e+00
# 25%    1.263397e+08            2017-08-19 18:00:00  1.400000e+01
# 50%    1.271823e+08            2017-08-23 12:00:00  2.750000e+01
# 75%    1.280249e+08            2017-08-27 06:00:00  4.100000e+01
# max    1.288675e+08            2017-08-31 00:00:00  5.400000e+01
# std    9.729693e+05                            NaN  1.558579e+01
#
#            item_nbr         class    perishable    dcoilwtico       cluster
# count  3.370464e+06  3.370464e+06  3.370464e+06  3.370464e+06  3.370464e+06
# mean   1.244798e+06  2.177082e+03  2.419892e-01  4.724333e+01  8.481481e+00
# min    9.699500e+04  1.002000e+03  0.000000e+00  4.596000e+01  1.000000e+00
# 25%    8.053210e+05  1.068000e+03  0.000000e+00  4.700250e+01  4.000000e+00
# ...

# %%
# save the file with changes

# for train file
train.to_csv("cleaned_merge_dataset_folder/pure_train_merge_dataset.csv", index= False)


# for test file
test.to_csv("cleaned_merge_dataset_folder/pure_test_merge_dataset.csv", index=False)

# %%
print(train.shape)
print(test.shape)
# Out:
# (1000000, 20)
# (3370464, 13)

# %% [markdown]
# # END
